# %%
# %load_ext autoreload
# %autoreload 2

# %%
#hide
from mynbmodule.core import *

# %% [markdown]
# # Project name here
#
# > Summary description here.

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# `pip install mynbmodule`

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
say_hello('John')
# Out:
# 'Hello John!'

# %%
say_goodbye('Diane')
# Out:
# 'See ya, Diane!'
